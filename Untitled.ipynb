# %%
import random

# %%
random.randint(1, 2)
# Out:
# 2

# %%
import nltk

# %%
nltk.corpus.words.words()
# Out:
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'Abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'Abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'Abanic',
#  'Abantes',
#  'abaptiston',
#  'Abarambo',
#  'Abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'Abasgi',
#  'abash',
#  'abashed',
# ...

# %%
random.choice(['o', '1'])
# Out:
# 'o'

# %%
import string
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
words
# Out:
# ['able',
#  'about',
#  'above',
#  'admit',
#  'adult',
#  'after',
#  'again',
#  'agent',
#  'agree',
#  'ahead',
#  'allow',
#  'alone',
#  'along',
#  'also',
#  'among',
#  'apply',
#  'area',
#  'argue',
#  'avoid',
#  'away',
#  'baby',
#  'back',
#  'ball',
#  'bank',
#  'base',
#  'beat',
#  'begin',
#  'best',
#  'bill',
#  'black',
#  'blood',
#  'blue',
#  'board',
#  'body',
#  'book',
#  'born',
#  'both',
#  'break',
#  'bring',
#  'build',
#  'call',
#  'card',
#  'care',
#  'carry',
#  'case',
#  'catch',
#  'cause',
#  'cell',
#  'chair',
#  'check',
#  'child',
#  'city',
#  'civil',
#  'claim',
#  'class',
#  'clear',
#  'close',
#  'coach',
#  'cold',
#  'color',
#  'come',
#  'cost',
#  'could',
#  'court',
#  'cover',
#  'crime',
#  'dark',
#  'data',
#  'dead',
#  'deal',
#  'death',
#  'deep',
#  'door',
#  'down',
#  'draw',
#  'dream',
#  'drive',
#  'drop',
#  'drug',
#  'each',
#  'early',
#  'east',
#  'easy',
#  'edge',
#  'eight',
#  'else',
# ...
